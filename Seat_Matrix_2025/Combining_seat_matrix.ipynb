# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.read_csv('Seat_Matrix_Female_Only.csv')

# %%
df1
# Out:
#                                          Institute Name  \
# 0           Indian Institute  of Technology Bhubaneswar
# 1           Indian Institute  of Technology Bhubaneswar
# 2           Indian Institute  of Technology Bhubaneswar
# 3           Indian Institute  of Technology Bhubaneswar
# 4           Indian Institute  of Technology Bhubaneswar
# ...                                                 ...
# 1344  Shri G. S. Institute of Technology and Science...
# 1345  Shri G. S. Institute of Technology and Science...
# 1346  Shri G. S. Institute of Technology and Science...
# 1347  Shri G. S. Institute of Technology and Science...
# 1348  Shri G. S. Institute of Technology and Science...
#
#                                            Program Name State/All India Seats  \
# 0     Civil Engineering (4 Years, Bachelor of Techno...             All India
# 1     Computer Science and Engineering (4 Years, Bac...             All India
# ...

# %%
len(df1)
# Out:
# 1349

# %%
df2 = pd.read_csv('Seat_Matrix_Gender_Neutral.csv')

# %%
df2
# Out:
#                                          Institute Name  \
# 0           Indian Institute  of Technology Bhubaneswar
# 1           Indian Institute  of Technology Bhubaneswar
# 2           Indian Institute  of Technology Bhubaneswar
# 3           Indian Institute  of Technology Bhubaneswar
# 4           Indian Institute  of Technology Bhubaneswar
# ...                                                 ...
# 1344  Shri G. S. Institute of Technology and Science...
# 1345  Shri G. S. Institute of Technology and Science...
# 1346  Shri G. S. Institute of Technology and Science...
# 1347  Shri G. S. Institute of Technology and Science...
# 1348  Shri G. S. Institute of Technology and Science...
#
#                                            Program Name State/All India Seats  \
# 0     Civil Engineering (4 Years, Bachelor of Techno...             All India
# 1     Computer Science and Engineering (4 Years, Bac...             All India
# ...

# %%
len(df2)
# Out:
# 1349

# %%
import pandas as pd

# Get common columns
common_cols = df1.columns

# Extract only the common columns from df1
df2_common = df2[common_cols]

# Create a new DataFrame by interleaving rows
interleaved_rows = []
for i in range(len(df2)):
    interleaved_rows.append(df2_common.iloc[i])
    interleaved_rows.append(df1.iloc[i])

# Convert to DataFrame
merged_df = pd.DataFrame(interleaved_rows)

# Optionally reset index
merged_df.reset_index(drop=True, inplace=True)

# %%
merged_df
# Out:
#                                          Institute Name  \
# 0           Indian Institute  of Technology Bhubaneswar
# 1           Indian Institute  of Technology Bhubaneswar
# 2           Indian Institute  of Technology Bhubaneswar
# 3           Indian Institute  of Technology Bhubaneswar
# 4           Indian Institute  of Technology Bhubaneswar
# ...                                                 ...
# 2693  Shri G. S. Institute of Technology and Science...
# 2694  Shri G. S. Institute of Technology and Science...
# 2695  Shri G. S. Institute of Technology and Science...
# 2696  Shri G. S. Institute of Technology and Science...
# 2697  Shri G. S. Institute of Technology and Science...
#
#                                            Program Name State/All India Seats  \
# 0     Civil Engineering (4 Years, Bachelor of Techno...             All India
# 1     Civil Engineering (4 Years, Bachelor of Techno...             All India
# ...

# %%
len(merged_df)
# Out:
# 2698

# %%
merged_df.to_csv("Merged_Seat_Matrix.csv" , index = False)
